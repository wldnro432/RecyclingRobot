# %%
# %cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pwd
# Out:
# /content

# %%
# %cd drive/MyDrive/Colab Notebooks/yolov7
# Out:
# /content/drive/MyDrive/Colab Notebooks/yolov7

# %%
# %cd yolov7
# Out:
# /content/drive/MyDrive/Colab Notebooks/yolov7

# %%
# !unzip data.zip

# %%
# !ls
# Out:
# coco.yaml  data.zip		    hyp.scratch.p5.yaml  hyp.scratch.tiny.yaml
# data.yaml  hyp.scratch.custom.yaml  hyp.scratch.p6.yaml  test

# %%
# %cd ../..
# Out:
# /content/drive/MyDrive/Colab Notebooks/yolov7

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data ./data/data.yaml --cfg ./cfg/training/yolov7.yaml --weights yolov7.pt --name recycling

# %%
# !python train.py --device 0 --batch-size 16 --epochs 100 --img 640 640 --data ./data/data/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --weights yolov7.pt --name yolov7-custom
# Out:
# YOLOR 🚀 2023-3-29 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7.yaml', data='./data/data/data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=100, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7-custom', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/yolov7-custom11', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python train.py --device 0 --batch-size 16 --epochs 100 --img 640 640 --data ./data/data/data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7.yaml --weights yolov7.pt --name yolov7-custom
# Out:
# YOLOR 🚀 2023-3-29 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7.yaml', data='./data/data/data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=100, batch_size=16, img_size=[640, 640], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7-custom', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/yolov7-custom12', total_batch_size=16)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/yolov7

# %%
# !find ./yolov7 -type d
# Out:
# ./yolov7
# ./yolov7/data
# ./yolov7/data/data
# ./yolov7/data/data/test
# ./yolov7/data/data/test/images
# ./yolov7/data/data/test/labels
# ./yolov7/data/data/train
# ./yolov7/data/data/train/images
# ./yolov7/data/data/train/labels
# ./yolov7/data/data/valid
# ./yolov7/data/data/valid/images
# ./yolov7/data/data/valid/labels
# ./yolov7/__pycache__
# ./yolov7/runs
# ./yolov7/runs/train
# ./yolov7/runs/train/yolov7-custom
# ./yolov7/runs/train/yolov7-custom/weights
# ./yolov7/runs/train/yolov7-custom2
# ./yolov7/runs/train/yolov7-custom2/weights
# ./yolov7/runs/train/yolov7-custom3
# ./yolov7/runs/train/yolov7-custom3/weights
# ./yolov7/runs/train/yolov7-custom4
# ./yolov7/runs/train/yolov7-custom4/weights
# ./yolov7/runs/train/yolov7-custom5
# ./yolov7/runs/train/yolov7-custom5/weights
# ./yolov7/runs/train/yolov7-custom6
# ./yolov7/runs/train/yolov7-custom6/weights
# ./yolov7/runs/train/yolov7-custom7
# ./yolov7/runs/train/yolov7-custom7/weights
# ./yolov7/runs/train/yolov7-custom8
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/yolov5/runs/

# %%
from IPython.display import Image
import os

val_img_path = val_img_list[4]

# !python detect.py --weights /content/yolov5/runs/exp0_gun_yolov5s_results/weights/best_gun_yolov5s_results.pt --img 416 --conf 0.5 --source "{val_img_path}"

Image(os.path.join('/content/yolov5/inference/output', os.path.basename(val_img_path)))
